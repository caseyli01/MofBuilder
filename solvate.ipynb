# %%
import numpy as np
import numpy as np
from scipy.spatial.transform import Rotation as R
from scipy.spatial import cKDTree


def read_xyz(filename):
    """
    Read an XYZ file and return:
        labels: list of atom symbols
        coords: numpy array of shape (N,3)
    """
    labels, coords = [], []
    with open(filename) as f:
        lines = f.readlines()
    for line in lines[2:]:
        parts = line.split()
        if len(parts) >= 4:
            labels.append(parts[0])
            coords.append([float(parts[1]), float(parts[2]), float(parts[3])])
    return labels, np.array(coords)


def generate_cluster_points(self,
                            target_number,
                            box_size,
                            min_distance=2.0,
                            cluster_center=None,
                            cluster_radius=None,
                            seed=None):
    """
    Generate points with minimum distance constraint, optionally clustered, fast and reproducible.

    Parameters
    ----------
    target_number : int
        Number of points to generate.
    box_size : array-like
        Box size in x, y, z.
    min_distance : float
        Minimum distance between points.
    cluster_center : array-like, optional
        Center of cluster. If None, points fill the box.
    cluster_radius : float, optional
        Radius of cluster sphere.
    seed : int, optional
        Random seed.

    Returns
    -------
    points : np.ndarray (target_number, 3)
    """
    rng = np.random.default_rng(seed)
    if self.buffer is not None:
        min_distance = max(min_distance, self.buffer)

    if cluster_center is not None and cluster_radius is not None:
        # Generate points on a cubic grid inside the sphere
        n_side = int(np.ceil((2 * cluster_radius) / min_distance))
        lin = np.linspace(-cluster_radius, cluster_radius, n_side)
        X, Y, Z = np.meshgrid(lin, lin, lin, indexing='ij')
        pts = np.vstack([X.ravel(), Y.ravel(), Z.ravel()]).T
        # Keep points inside the sphere
        mask = np.linalg.norm(pts, axis=1) <= cluster_radius
        pts = pts[mask] + cluster_center
    else:
        # Generate points on a cubic grid inside the box
        n_side = [int(np.ceil(bs / min_distance)) for bs in box_size]
        linx = np.linspace(0, box_size[0], n_side[0], endpoint=False)
        liny = np.linspace(0, box_size[1], n_side[1], endpoint=False)
        linz = np.linspace(0, box_size[2], n_side[2], endpoint=False)
        X, Y, Z = np.meshgrid(linx, liny, linz, indexing='ij')
        pts = np.vstack([X.ravel(), Y.ravel(), Z.ravel()]).T

    # Shuffle and pick required number
    rng.shuffle(pts)
    if pts.shape[0] < target_number:
        raise RuntimeError(
            f"Not enough points generated: {pts.shape[0]} < {target_number}")
        return pts
    return pts[:target_number]


def generate_candidates_each_solvent(solvent_coords,
                                     solvent_labels,
                                     box_size,
                                     target_number,
                                     residue_idx_start=0,
                                     points_template=None):
    """
    Vectorized tiling and rotation of solvent molecules.
    Returns:
        candidates: (N_atoms_total,3)
        labels: (N_atoms_total,)
        residue_idx: (N_atoms_total,)
    """
    n_atoms = solvent_coords.shape[0]

    # Random translations and rotations
    if points_template is None:
        #random_points = np.random.rand(target_number, 3) * box_size
        random_points = generate_cluster_points(target_number,
                                                box_size,
                                                min_distance=2.0,
                                                seed=42)  # (target_number,3)
    else:
        random_points = points_template
    rots = R.random(target_number).as_matrix()  # (target_number,3,3)

    n_atoms = solvent_coords.shape[0]
    coords_exp = solvent_coords[np.newaxis, :, :]  # (1, n_atoms, 3)
    # rots: (n_tiles, 3, 3)
    rot_coords = np.matmul(coords_exp,
                           rots.transpose(0, 2, 1))  # (n_tiles, n_atoms, 3)

    candidates = rot_coords.reshape(-1, 3)
    candidates += np.repeat(random_points, n_atoms, axis=0)
    labels = np.array(list(solvent_labels) * target_number).reshape(-1, 1)
    residue_idx = np.repeat(
        np.arange(residue_idx_start, residue_idx_start + target_number),
        n_atoms).reshape(-1, 1)

    return candidates, labels, residue_idx


# -----------------------------
# Step 3: Remove overlapping residues (fast vectorized)
# -----------------------------


def remove_overlaps_kdtree(existing_coords, candidate_coords,
                           candidate_residues, buffer):
    """
    Remove solvent residues that overlap with:
        1. existing atoms (solute + accepted solvents)
        2. other candidate residues themselves

    Parameters
    ----------
    existing_coords : np.ndarray (Ne,3)
        Coordinates of solute + previously accepted solvents.
    candidate_coords : np.ndarray (Nc,3)
        Coordinates of candidate solvent atoms.
    candidate_residues : np.ndarray (Nc,)
        Residue index for each candidate atom.
    buffer : float
        Minimum allowed distance.

    Returns
    -------
    keep_mask : np.ndarray (Nc,), bool
        Mask indicating kept atoms.
    drop_mask : np.ndarray (Nc,), bool
        Mask indicating dropped atoms.
    """
    # Ensure candidate_residues is 1D
    candidate_residues = candidate_residues.reshape(-1)

    # --- Round 1: Overlap with existing atoms ---
    tree_existing = cKDTree(existing_coords)
    neighbors_existing = tree_existing.query_ball_point(candidate_coords,
                                                        r=buffer)
    mask_overlap_existing = np.array(
        [len(neigh) > 0 for neigh in neighbors_existing])
    bad_residues_existing = np.unique(
        candidate_residues[mask_overlap_existing])

    # --- Round 2: Overlap among candidates themselves ---
    tree_candidates = cKDTree(candidate_coords)
    neighbors_candidates = tree_candidates.query_ball_point(candidate_coords,
                                                            r=buffer)

    # A candidate overlaps if it has neighbors (excluding itself)
    #bad residues should be if find neighbors but not the residue itself, so based on residue index
    mask_overlap_candidates = np.array([
        any(candidate_residues[neigh] != candidate_residues[i]
            for neigh in neighbors_candidates[i] if neigh != i)
        for i in range(len(candidate_coords))
    ])
    bad_residues_candidates = np.unique(
        candidate_residues[mask_overlap_candidates])

    # --- Combine bad residues from both rounds ---
    bad_residues = np.union1d(bad_residues_existing, bad_residues_candidates)

    keep_mask = ~np.isin(candidate_residues, bad_residues)
    drop_mask = ~keep_mask  # same length as candidate_residues

    return keep_mask, drop_mask


def _remove_overlaps_kdtree(existing_coords, candidate_coords,
                            candidate_residues, buffer):
    print(
        f"shape check: existing_coords {existing_coords.shape}, candidate_coords {candidate_coords.shape}, candidate_residues {candidate_residues.shape}"
    )
    """
    Remove solvent residues that overlap with existing atoms using KDTree.
    
    Parameters:
        existing_coords: np.ndarray (Ne,3) - coordinates of solute + previously accepted solvents
        candidate_coords: np.ndarray (Nc,3) - coordinates of candidate solvent atoms
        candidate_residues: np.ndarray (Nc,) - residue index for each candidate atom
        buffer: float - minimum allowed distance
        
    Returns:
        filtered_candidate_coords: np.ndarray
        filtered_candidate_residues: np.ndarray
        keep_mask: boolean array of length Nc indicating kept atoms
    """
    #reshape candidate_residues to ensure it's a 1D array
    candidate_residues = candidate_residues.reshape(-1)
    # Build KDTree for existing atoms
    tree = cKDTree(existing_coords)

    # Query all candidate atoms for neighbors within buffer
    # Returns list of neighbor indices for each candidate atom
    neighbors = tree.query_ball_point(candidate_coords, r=buffer)

    # Candidate atoms that have at least one neighbor are overlapping
    mask_overlap = np.array([len(neigh) > 0 for neigh in neighbors])

    # Identify residues to remove
    bad_residues = np.unique(candidate_residues[mask_overlap])

    # Keep atoms whose residue is not in bad_residues
    keep_mask = ~np.isin(candidate_residues, bad_residues)
    drop_mask = np.isin(candidate_residues, bad_residues)

    filtered_candidate_coords = candidate_coords[keep_mask]
    filtered_candidate_residues = candidate_residues[keep_mask]

    return keep_mask, drop_mask


# -----------------------------
# Step 4: Cluster isolated cavity points
# -----------------------------
def cluster_candidates(candidate_coords, candidate_residues, cluster_radius):
    """
    Cluster candidate residues using nearest neighbor distance threshold.
    Returns cluster centers and representative residue indices.
    """
    #check shape of candidate_residues
    candidate_residues = candidate_residues.reshape(-1)
    # Compute centers of each unique residue
    unique_residues = np.unique(candidate_residues)
    centers = np.array([
        candidate_coords[candidate_residues == res].astype(
            np.float32).mean(axis=0) for res in unique_residues
    ])

    # Flatten pairwise distances
    diff = centers[:, None, :] - centers[None, :, :]
    dist2 = np.sum(diff**2, axis=2)

    # Build mask for neighbors
    neighbors_mask = dist2 < cluster_radius**2
    np.fill_diagonal(neighbors_mask, False)

    # Accept centers that have no neighbor within cluster_radius
    isolated_mask = ~np.any(neighbors_mask, axis=1)
    accepted_centers = centers[isolated_mask]
    accepted_residues = unique_residues[isolated_mask]

    return accepted_centers, accepted_residues


_solute_labels, _solute_coords = read_xyz(
    "output/UiO-66_mofbuilder_output.xyz")
_water_labels, _water_coords = read_xyz("water.xyz")
_dmso_labels, _dmso_coords = read_xyz("dmso.xyz")
box_size = [30.0, 30.0, 30.0]  # Define your box size
target_water_number = 1000  # Target number of water molecules
target_dmso_number = 500  # Target number of DMSO molecules
buffer = 1.0  # Minimum distance to existing atoms
water_candidates, water_labels, water_residue_idx = generate_candidates_each_solvent(
    _water_coords,
    _water_labels,
    box_size,
    target_water_number,
    residue_idx_start=0)
dmso_candidates, dmso_labels, dmso_residue_idx = generate_candidates_each_solvent(
    _dmso_coords,
    _dmso_labels,
    box_size,
    target_dmso_number,
    residue_idx_start=target_water_number)

water_candidates_info = np.hstack(
    (water_residue_idx, water_labels, water_candidates))
dmso_candidates_info = np.hstack(
    (dmso_residue_idx, dmso_labels, dmso_candidates))
all_candidates_info = np.vstack((water_candidates_info, dmso_candidates_info))
all_candidate_coords = all_candidates_info[:, 2:5]
all_candidate_labels = all_candidates_info[:, 1]
all_candidate_residues = all_candidates_info[:, 0].astype(int)

# Minimum distance to existing atoms
print("Total candidate atoms:", all_candidate_coords.shape[0])
keep_mask, drop_mask = remove_overlaps_kdtree(_solute_coords,
                                              all_candidate_coords,
                                              all_candidate_residues, buffer)
print("Number of accepted candidate atoms:", np.sum(keep_mask))
keep_candidate_coords = all_candidate_coords[keep_mask]
keep_candidate_labels = all_candidate_labels[keep_mask]

cavity_coords = all_candidate_coords[drop_mask]
cavity_residues = all_candidate_residues[drop_mask]
cavity_labels = all_candidate_labels[drop_mask]

possible_centers, possible_residues = cluster_candidates(cavity_coords,
                                                         cavity_residues,
                                                         cluster_radius=3.0)
print("Number of possible centers:", possible_centers.shape)

#regenerate solvent molecules at possible centers
round2water_candidates, round2water_labels, round2water_residue_idx = generate_candidates_each_solvent(
    _water_coords,
    _water_labels,
    box_size,
    target_number=possible_centers.shape[0],
    residue_idx_start=target_water_number + target_dmso_number,
    points_template=possible_centers)

round2water_info = np.hstack(
    (round2water_residue_idx, round2water_labels, round2water_candidates))

print("Number of newly added water atoms:", keep_candidate_coords.shape)

round2_keep_mask, round2_drop_mask = remove_overlaps_kdtree(
    keep_candidate_coords, round2water_candidates, round2water_residue_idx,
    buffer)

#use possible centers to add solvent molecules repeatedly until no more can be added, if no possible centersm then get a random dots in the box
round2_keep_candidate_coords = round2water_candidates[round2_keep_mask]
round2_keep_candidate_labels = round2water_labels[round2_keep_mask]
round2_cavity_coords = round2water_candidates[round2_drop_mask]
round2_cavity_residues = round2water_residue_idx[round2_drop_mask]
round2_cavity_labels = round2water_labels[round2_drop_mask]

round2_possible_centers, round2_possible_residues = cluster_candidates(
    round2_cavity_coords, round2_cavity_residues, cluster_radius=3.0)
print("Number of possible centers:", round2_possible_centers.shape)

#merge the two sets of kept candidates
final_candidate_coords = np.vstack(
    (_solute_coords, keep_candidate_coords, round2_keep_candidate_coords))
#merge the 1d arrays of labels
final_candidate_labels = np.hstack(
    (np.array(_solute_labels), keep_candidate_labels,
     round2_keep_candidate_labels.flatten()))

data = np.hstack((final_candidate_labels.reshape(-1,
                                                 1), final_candidate_coords))

#write to xyz file
with open("solvated_structure.xyz", "w") as fp:
    fp.write(f"{data.shape[0]}\n")
    fp.write("Solvated structure\n")
    for row in data:
        fp.write(
            f"{row[0]} {float(row[1]):.4f} {float(row[2]):.4f} {float(row[3]):.4f}\n"
        )
print(len(data), "atoms written to solvated_structure.xyz")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 277
#     275 target_dmso_number = 500  # Target number of DMSO molecules
#     276 buffer = 1.0  # Minimum distance to existing atoms
# --> 277 water_candidates, water_labels, water_residue_idx = generate_candidates_each_solvent(
#     278     _water_coords,
#     279     _water_labels,
#     280     box_size,
#     281     target_water_number,
#     282     residue_idx_start=0)
#     283 dmso_candidates, dmso_labels, dmso_residue_idx = generate_candidates_each_solvent(
#     284     _dmso_coords,
#     285     _dmso_labels,
#     286     box_size,
#     287     target_dmso_number,
#     288     residue_idx_start=target_water_number)
#     290 water_candidates_info = np.hstack(
#     291     (water_residue_idx, water_labels, water_candidates))
#
# Cell In[87], line 102, in generate_candidates_each_solvent(solvent_coords, solvent_labels, box_size, target_number, residue_idx_start, points_template)
#      99 # Random translations and rotations
#     100 if points_template is None:
#     101     #random_points = np.random.rand(target_number, 3) * box_size
# --> 102     random_points = generate_cluster_points(target_number,
#     103                                             box_size,
#     104                                             min_distance=2.0,
#     105                                             seed=42)  # (target_number,3)
#     106 else:
#     107     random_points = points_template
#
# TypeError: generate_cluster_points() missing 1 required positional argument: 'box_size'

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R
from scipy.spatial import cKDTree


class SolventPacker:

    def __init__(self, buffer=1.0, box_size=(30.0, 30.0, 30.0)):
        """
        Parameters
        ----------
        buffer : float
            Minimum allowed distance between atoms.
        box_size : tuple of float
            Dimensions of the box for placing solvents.
        """
        self.buffer = buffer
        self.box_size = np.array(box_size)
        self.verbose = True

    def read_xyz(self, filename):
        labels, coords = [], []
        with open(filename) as f:
            lines = f.readlines()
        for line in lines[2:]:
            parts = line.split()
            if len(parts) >= 4:
                labels.append(parts[0])
                coords.append(
                    [float(parts[1]),
                     float(parts[2]),
                     float(parts[3])])
        return labels, np.array(coords)

    def generate_cluster_points(self,
                                target_number,
                                box_size,
                                min_distance=0.5,
                                cluster_center=None,
                                cluster_radius=None,
                                seed=None):
        """
        Generate points with minimum distance constraint, optionally clustered, fast and reproducible.

        Parameters
        ----------
        target_number : int
            Number of points to generate.
        box_size : array-like
            Box size in x, y, z.
        min_distance : float
            Minimum distance between points.
        cluster_center : array-like, optional
            Center of cluster. If None, points fill the box.
        cluster_radius : float, optional
            Radius of cluster sphere.
        seed : int, optional
            Random seed.

        Returns
        -------
        points : np.ndarray (target_number, 3)
        """
        rng = np.random.default_rng(seed)

        if cluster_center is not None and cluster_radius is not None:
            # Generate points on a cubic grid inside the sphere
            n_side = int(np.ceil((2 * cluster_radius) / min_distance))
            lin = np.linspace(-cluster_radius, cluster_radius, n_side)
            X, Y, Z = np.meshgrid(lin, lin, lin, indexing='ij')
            pts = np.vstack([X.ravel(), Y.ravel(), Z.ravel()]).T
            # Keep points inside the sphere
            mask = np.linalg.norm(pts, axis=1) <= cluster_radius
            pts = pts[mask] + cluster_center
        else:
            # Generate points on a cubic grid inside the box
            n_side = [int(np.ceil(bs / min_distance)) for bs in box_size]
            linx = np.linspace(0, box_size[0], n_side[0], endpoint=False)
            liny = np.linspace(0, box_size[1], n_side[1], endpoint=False)
            linz = np.linspace(0, box_size[2], n_side[2], endpoint=False)
            X, Y, Z = np.meshgrid(linx, liny, linz, indexing='ij')
            pts = np.vstack([X.ravel(), Y.ravel(), Z.ravel()]).T

        # Shuffle and pick required number
        rng.shuffle(pts)
        if pts.shape[0] < target_number:
            print(
                f"Not enough points generated: {pts.shape[0]} < {target_number}"
            )
            return pts
        return pts[:target_number]

    def generate_candidates_each_solvent(self,
                                         solvent_coords,
                                         solvent_labels,
                                         target_number,
                                         residue_idx_start=0,
                                         points_template=None):
        n_atoms = solvent_coords.shape[0]
        if points_template is None:
            random_points = np.random.rand(target_number, 3) * self.box_size
            #random_points = self.generate_cluster_points(
            #    target_number, self.box_size, min_distance=2.0,
            #    seed=42)  # (target_number,3)
        else:
            random_points = points_template
        target_number = random_points.shape[0]

        rots = R.random(target_number).as_matrix()
        coords_exp = solvent_coords[np.newaxis, :, :]
        rot_coords = np.matmul(coords_exp, rots.transpose(0, 2, 1))
        candidates = rot_coords.reshape(-1, 3)
        candidates += np.repeat(random_points, n_atoms, axis=0)

        labels = np.array(list(solvent_labels) * target_number).reshape(-1, 1)
        residue_idx = np.repeat(
            np.arange(residue_idx_start, residue_idx_start + target_number),
            n_atoms).reshape(-1, 1)

        return candidates, labels, residue_idx

    def remove_overlaps_kdtree(self, existing_coords, candidate_coords,
                               candidate_residues):
        candidate_residues = candidate_residues.reshape(-1)

        # Round 1: overlap with existing atoms
        tree_existing = cKDTree(existing_coords)
        neighbors_existing = tree_existing.query_ball_point(candidate_coords,
                                                            r=self.buffer)
        mask_overlap_existing = np.array(
            [len(neigh) > 0 for neigh in neighbors_existing])
        bad_residues_existing = np.unique(
            candidate_residues[mask_overlap_existing])

        # Round 2: overlap among candidates
        tree_candidates = cKDTree(candidate_coords)
        neighbors_candidates = tree_candidates.query_ball_point(
            candidate_coords, r=self.buffer)
        mask_overlap_candidates = np.array([
            any(candidate_residues[neigh] != candidate_residues[i]
                for neigh in neighbors_candidates[i] if neigh != i)
            for i in range(len(candidate_coords))
        ])
        bad_residues_candidates = np.unique(
            candidate_residues[mask_overlap_candidates])

        bad_residues = np.union1d(bad_residues_existing,
                                  bad_residues_candidates)
        keep_mask = ~np.isin(candidate_residues, bad_residues)
        drop_mask = ~keep_mask
        return keep_mask, drop_mask

    def _remove_overlaps_kdtree(self, existing_coords, candidate_coords,
                                candidate_residues):
        print(f"shape check: existing_coords {existing_coords.shape}, "
              f"candidate_coords {candidate_coords.shape}, "
              f"candidate_residues {candidate_residues.shape}")
        candidate_residues = candidate_residues.reshape(-1)
        tree = cKDTree(existing_coords)
        neighbors = tree.query_ball_point(candidate_coords, r=self.buffer)
        mask_overlap = np.array([len(neigh) > 0 for neigh in neighbors])
        bad_residues = np.unique(candidate_residues[mask_overlap])
        keep_mask = ~np.isin(candidate_residues, bad_residues)
        drop_mask = np.isin(candidate_residues, bad_residues)

        filtered_candidate_coords = candidate_coords[keep_mask]
        filtered_candidate_residues = candidate_residues[keep_mask]

        return keep_mask, drop_mask

    def cluster_candidates(self, candidate_coords, candidate_residues,
                           cluster_radius):
        candidate_residues = candidate_residues.reshape(-1)
        unique_residues = np.unique(candidate_residues)
        centers = np.array([
            candidate_coords[candidate_residues == res].astype(
                np.float32).mean(axis=0) for res in unique_residues
        ])

        diff = centers[:, None, :] - centers[None, :, :]
        dist2 = np.sum(diff**2, axis=2)
        neighbors_mask = dist2 < cluster_radius**2
        np.fill_diagonal(neighbors_mask, False)

        isolated_mask = ~np.any(neighbors_mask, axis=1)
        accepted_centers = centers[isolated_mask]
        accepted_residues = unique_residues[isolated_mask]

        return accepted_centers, accepted_residues

    def solvate(self,
                solute_file,
                water_file,
                dmso_file,
                target_water_number=1000,
                target_dmso_number=500,
                output_file="solvated_structure.xyz",
                trial_rounds=10):

        # --- read solute and solvents ---
        _solute_labels, _solute_coords = self.read_xyz(solute_file)
        _water_labels, _water_coords = self.read_xyz(water_file)
        _dmso_labels, _dmso_coords = self.read_xyz(dmso_file)

        best_coords = None
        best_labels = None
        max_added = 0

        # --- Trial loop for 10 random seeds ---
        for trial in range(trial_rounds):
            if self.verbose:
                print(f"Trial {trial+1}/{trial_rounds},before{max_added}")

            np.random.seed(trial)  # different random seed for each trial

            # --- Generate initial solvent candidates ---
            water_candidates, water_labels, water_residue_idx = self.generate_candidates_each_solvent(
                _water_coords,
                _water_labels,
                target_water_number,
                residue_idx_start=0)
            dmso_candidates, dmso_labels, dmso_residue_idx = self.generate_candidates_each_solvent(
                _dmso_coords,
                _dmso_labels,
                target_dmso_number,
                residue_idx_start=target_water_number)

            all_candidates_info = np.vstack(
                (np.hstack(
                    (water_residue_idx, water_labels, water_candidates)),
                 np.hstack((dmso_residue_idx, dmso_labels, dmso_candidates))))

            all_candidate_coords = all_candidates_info[:, 2:5].astype(float)
            all_candidate_labels = all_candidates_info[:, 1]
            all_candidate_residues = all_candidates_info[:, 0].astype(int)

            print(
                f"Generated {all_candidate_coords.shape[0]} initial solvent candidates."
            )

            # --- Round 1 overlap removal ---
            keep_mask, drop_mask = self.remove_overlaps_kdtree(
                _solute_coords, all_candidate_coords, all_candidate_residues)
            accepted_coords = all_candidate_coords[keep_mask]
            accepted_labels = all_candidate_labels[keep_mask]
            cavity_coords = all_candidate_coords[drop_mask]
            cavity_residues = all_candidate_residues[drop_mask]

            print(
                f"After Round 1 overlap removal: {accepted_coords.shape[0]} accepted, {cavity_coords.shape[0]} left in cavity."
            )

            # --- Iterative cavity filling (big round) ---
            max_fill_rounds = 1000
            round_idx = 0
            while round_idx < max_fill_rounds and cavity_coords.shape[0] > 0:
                round_idx += 1
                possible_centers, _ = self.cluster_candidates(
                    cavity_coords, cavity_residues, cluster_radius=self.buffer)
                print(
                    f"Round {round_idx}: {possible_centers.shape[0]} possible centers identified."
                )

                if possible_centers.shape[0] == 0:
                    break

                round_candidates, round_labels, round_residues = self.generate_candidates_each_solvent(
                    _water_coords,
                    _water_labels,
                    target_number=possible_centers.shape[0],
                    residue_idx_start=accepted_coords.shape[0],
                    points_template=possible_centers)

                keep_mask, drop_mask = self.remove_overlaps_kdtree(
                    accepted_coords, round_candidates, round_residues)
                round_keep_coords = round_candidates[keep_mask]
                round_keep_labels = round_labels[keep_mask]

                print(
                    f"Round {round_idx}: {round_keep_coords.shape[0]} added, {round_candidates[drop_mask].shape[0]} left in cavity."
                )

                if round_keep_coords.shape[0] == 0:
                    break

                # Update accepted molecules
                accepted_coords = np.vstack(
                    (accepted_coords, round_keep_coords))
                accepted_labels = np.hstack(
                    (accepted_labels, round_keep_labels.flatten()))

                # Update cavity for next iteration
                cavity_coords = round_candidates[drop_mask]
                cavity_residues = round_residues[drop_mask]

            # --- Update best trial ---
            print(
                f"after{max_added},accepted_coords shape {accepted_coords.shape},solute shape {_solute_coords.shape}"
            )
            n_added = accepted_coords.shape[0]
            if n_added > max_added:
                max_added = n_added
                best_coords = accepted_coords.copy()
                best_labels = accepted_labels.copy()
                if self.verbose:
                    print(
                        f"Trial {trial+1} is new best with {n_added} added atoms."
                    )

        # --- Merge solute and best solvent trial ---
        if best_coords is not None:
            final_coords = np.vstack(
                (_solute_coords, best_coords.astype(float)))
        else:
            raise ValueError(
                "No valid solvent molecules were added in any trial.")
        final_labels = np.hstack((_solute_labels, best_labels))

        # --- Write xyz ---
        with open(output_file, "w") as fp:
            fp.write(f"{final_coords.shape[0]}\n")
            fp.write("Solvated structure\n")
            for label, (x, y, z) in zip(final_labels, final_coords):
                fp.write(f"{label} {x:.4f} {y:.4f} {z:.4f}\n")

        if self.verbose:
            print(len(final_coords), "atoms written to", output_file)
            print("Best trial added", max_added, "solvent atoms.")

        return final_coords, final_labels

# %%
box_size = [80.0, 50.0, 50.0]  # Å³
water_density = 1.0  # g/cm³
water_molar_mass = 18.015  # g/mol


def solvent_number_from_density(box_size, density, molar_mass):
    """
    Compute the number of solvent molecules to fill a box at given density.

    Parameters
    ----------
    box_size : array-like of length 3
        Box size in Angstroms [x, y, z]
    density : float
        Density in g/cm³
    molar_mass : float
        Molar mass in g/mol

    Returns
    -------
    n_molecules : int
        Number of solvent molecules to generate
    """
    V_A3 = np.prod(box_size)  # Å³
    V_cm3 = V_A3 * 1e-24  # cm³
    N_A = 6.022e23  # Avogadro's number
    n_molecules = int(density * V_cm3 * N_A / molar_mass)
    return n_molecules


n_water = solvent_number_from_density(box_size, water_density,
                                      water_molar_mass)
print("Number of water molecules:", n_water)

dmso_density = 1.1  # g/cm³
dmso_molar_mass = 78.13  # g/mol
n_dmso = solvent_number_from_density(box_size, dmso_density, dmso_molar_mass)
print("Number of DMSO molecules:", n_dmso)
# Out:
# Number of water molecules: 6685
# Number of DMSO molecules: 1695

# %%
packer = SolventPacker(buffer=1, box_size=(80.0, 50.0, 50.0))
packer.solvate(solute_file="output/UiO-66_mofbuilder_output.xyz",
               water_file="water.xyz",
               dmso_file="dmso.xyz",
               target_water_number=4000,
               target_dmso_number=20,
               output_file="solvated_structure.xyz",
               trial_rounds=50)
# Out:
# Trial 1/50,before0
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7267 accepted, 4933 left in cavity.
# Round 1: 1316 possible centers identified.
# Round 1: 2664 added, 1284 left in cavity.
# Round 2: 378 possible centers identified.
# Round 2: 732 added, 402 left in cavity.
# Round 3: 124 possible centers identified.
# Round 3: 225 added, 147 left in cavity.
# Round 4: 47 possible centers identified.
# Round 4: 96 added, 45 left in cavity.
# Round 5: 15 possible centers identified.
# Round 5: 30 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 9 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 3 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 0 added, 3 left in cavity.
# after0,accepted_coords shape (11026, 3),solute shape (8326, 3)
# Trial 1 is new best with 11026 added atoms.
# Trial 2/50,before11026
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6963 accepted, 5237 left in cavity.
# Round 1: 1412 possible centers identified.
# Round 1: 2847 added, 1389 left in cavity.
# Round 2: 387 possible centers identified.
# Round 2: 834 added, 327 left in cavity.
# Round 3: 99 possible centers identified.
# Round 3: 183 added, 114 left in cavity.
# Round 4: 38 possible centers identified.
# Round 4: 69 added, 45 left in cavity.
# Round 5: 15 possible centers identified.
# Round 5: 36 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 6 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11026,accepted_coords shape (10938, 3),solute shape (8326, 3)
# Trial 3/50,before11026
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6950 accepted, 5250 left in cavity.
# Round 1: 1419 possible centers identified.
# Round 1: 3009 added, 1248 left in cavity.
# Round 2: 355 possible centers identified.
# Round 2: 711 added, 354 left in cavity.
# Round 3: 116 possible centers identified.
# Round 3: 216 added, 132 left in cavity.
# Round 4: 44 possible centers identified.
# Round 4: 78 added, 54 left in cavity.
# Round 5: 18 possible centers identified.
# Round 5: 27 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 12 added, 15 left in cavity.
# Round 7: 5 possible centers identified.
# Round 7: 12 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 3 added, 0 left in cavity.
# after11026,accepted_coords shape (11018, 3),solute shape (8326, 3)
# Trial 4/50,before11026
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7064 accepted, 5136 left in cavity.
# Round 1: 1388 possible centers identified.
# Round 1: 2808 added, 1356 left in cavity.
# Round 2: 402 possible centers identified.
# Round 2: 822 added, 384 left in cavity.
# Round 3: 120 possible centers identified.
# Round 3: 234 added, 126 left in cavity.
# Round 4: 40 possible centers identified.
# Round 4: 87 added, 33 left in cavity.
# Round 5: 11 possible centers identified.
# Round 5: 27 added, 6 left in cavity.
# Round 6: 2 possible centers identified.
# Round 6: 3 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11026,accepted_coords shape (11045, 3),solute shape (8326, 3)
# Trial 4 is new best with 11045 added atoms.
# Trial 5/50,before11045
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7090 accepted, 5110 left in cavity.
# Round 1: 1378 possible centers identified.
# Round 1: 2949 added, 1185 left in cavity.
# Round 2: 353 possible centers identified.
# Round 2: 702 added, 357 left in cavity.
# Round 3: 113 possible centers identified.
# Round 3: 213 added, 126 left in cavity.
# Round 4: 42 possible centers identified.
# Round 4: 72 added, 54 left in cavity.
# Round 5: 18 possible centers identified.
# Round 5: 24 added, 30 left in cavity.
# Round 6: 10 possible centers identified.
# Round 6: 21 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 0 added, 9 left in cavity.
# after11045,accepted_coords shape (11071, 3),solute shape (8326, 3)
# Trial 5 is new best with 11071 added atoms.
# Trial 6/50,before11071
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7111 accepted, 5089 left in cavity.
# Round 1: 1395 possible centers identified.
# Round 1: 2820 added, 1365 left in cavity.
# Round 2: 397 possible centers identified.
# Round 2: 852 added, 339 left in cavity.
# Round 3: 107 possible centers identified.
# Round 3: 216 added, 105 left in cavity.
# Round 4: 33 possible centers identified.
# Round 4: 60 added, 39 left in cavity.
# Round 5: 13 possible centers identified.
# Round 5: 24 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 12 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 3 added, 0 left in cavity.
# after11071,accepted_coords shape (11098, 3),solute shape (8326, 3)
# Trial 6 is new best with 11098 added atoms.
# Trial 7/50,before11098
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7106 accepted, 5094 left in cavity.
# Round 1: 1373 possible centers identified.
# Round 1: 2757 added, 1362 left in cavity.
# Round 2: 408 possible centers identified.
# Round 2: 834 added, 390 left in cavity.
# Round 3: 128 possible centers identified.
# Round 3: 234 added, 150 left in cavity.
# Round 4: 50 possible centers identified.
# Round 4: 99 added, 51 left in cavity.
# Round 5: 17 possible centers identified.
# Round 5: 30 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 15 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 6 added, 0 left in cavity.
# after11098,accepted_coords shape (11081, 3),solute shape (8326, 3)
# Trial 8/50,before11098
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7111 accepted, 5089 left in cavity.
# Round 1: 1392 possible centers identified.
# Round 1: 2814 added, 1362 left in cavity.
# Round 2: 418 possible centers identified.
# Round 2: 792 added, 462 left in cavity.
# Round 3: 146 possible centers identified.
# Round 3: 258 added, 180 left in cavity.
# Round 4: 60 possible centers identified.
# Round 4: 99 added, 81 left in cavity.
# Round 5: 27 possible centers identified.
# Round 5: 57 added, 24 left in cavity.
# Round 6: 8 possible centers identified.
# Round 6: 15 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 9 added, 0 left in cavity.
# after11098,accepted_coords shape (11155, 3),solute shape (8326, 3)
# Trial 8 is new best with 11155 added atoms.
# Trial 9/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7126 accepted, 5074 left in cavity.
# Round 1: 1355 possible centers identified.
# Round 1: 2829 added, 1236 left in cavity.
# Round 2: 357 possible centers identified.
# Round 2: 720 added, 351 left in cavity.
# Round 3: 115 possible centers identified.
# Round 3: 219 added, 126 left in cavity.
# Round 4: 40 possible centers identified.
# Round 4: 72 added, 48 left in cavity.
# Round 5: 16 possible centers identified.
# Round 5: 27 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 18 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (11014, 3),solute shape (8326, 3)
# Trial 10/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6980 accepted, 5220 left in cavity.
# Round 1: 1390 possible centers identified.
# Round 1: 2811 added, 1359 left in cavity.
# Round 2: 401 possible centers identified.
# Round 2: 795 added, 408 left in cavity.
# Round 3: 128 possible centers identified.
# Round 3: 258 added, 126 left in cavity.
# Round 4: 40 possible centers identified.
# Round 4: 72 added, 48 left in cavity.
# Round 5: 14 possible centers identified.
# Round 5: 30 added, 12 left in cavity.
# Round 6: 4 possible centers identified.
# Round 6: 9 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (10958, 3),solute shape (8326, 3)
# Trial 11/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7150 accepted, 5050 left in cavity.
# Round 1: 1361 possible centers identified.
# Round 1: 2820 added, 1263 left in cavity.
# Round 2: 369 possible centers identified.
# Round 2: 759 added, 348 left in cavity.
# Round 3: 108 possible centers identified.
# Round 3: 213 added, 111 left in cavity.
# Round 4: 37 possible centers identified.
# Round 4: 66 added, 45 left in cavity.
# Round 5: 15 possible centers identified.
# Round 5: 33 added, 12 left in cavity.
# Round 6: 4 possible centers identified.
# Round 6: 6 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 3 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (11053, 3),solute shape (8326, 3)
# Trial 12/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6935 accepted, 5265 left in cavity.
# Round 1: 1420 possible centers identified.
# Round 1: 2916 added, 1344 left in cavity.
# Round 2: 410 possible centers identified.
# Round 2: 840 added, 390 left in cavity.
# Round 3: 124 possible centers identified.
# Round 3: 195 added, 177 left in cavity.
# Round 4: 59 possible centers identified.
# Round 4: 111 added, 66 left in cavity.
# Round 5: 22 possible centers identified.
# Round 5: 45 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 15 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 3 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 0 added, 3 left in cavity.
# after11155,accepted_coords shape (11060, 3),solute shape (8326, 3)
# Trial 13/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6915 accepted, 5285 left in cavity.
# Round 1: 1427 possible centers identified.
# Round 1: 2835 added, 1446 left in cavity.
# Round 2: 423 possible centers identified.
# Round 2: 918 added, 351 left in cavity.
# Round 3: 113 possible centers identified.
# Round 3: 219 added, 120 left in cavity.
# Round 4: 38 possible centers identified.
# Round 4: 78 added, 36 left in cavity.
# Round 5: 12 possible centers identified.
# Round 5: 27 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 9 added, 0 left in cavity.
# after11155,accepted_coords shape (11001, 3),solute shape (8326, 3)
# Trial 14/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7017 accepted, 5183 left in cavity.
# Round 1: 1408 possible centers identified.
# Round 1: 2934 added, 1290 left in cavity.
# Round 2: 392 possible centers identified.
# Round 2: 744 added, 432 left in cavity.
# Round 3: 136 possible centers identified.
# Round 3: 264 added, 144 left in cavity.
# Round 4: 48 possible centers identified.
# Round 4: 96 added, 48 left in cavity.
# Round 5: 16 possible centers identified.
# Round 5: 21 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 21 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 0 added, 6 left in cavity.
# after11155,accepted_coords shape (11097, 3),solute shape (8326, 3)
# Trial 15/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6978 accepted, 5222 left in cavity.
# Round 1: 1392 possible centers identified.
# Round 1: 2769 added, 1407 left in cavity.
# Round 2: 405 possible centers identified.
# Round 2: 867 added, 348 left in cavity.
# Round 3: 114 possible centers identified.
# Round 3: 195 added, 147 left in cavity.
# Round 4: 47 possible centers identified.
# Round 4: 78 added, 63 left in cavity.
# Round 5: 21 possible centers identified.
# Round 5: 42 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 18 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11155,accepted_coords shape (10947, 3),solute shape (8326, 3)
# Trial 16/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7073 accepted, 5127 left in cavity.
# Round 1: 1370 possible centers identified.
# Round 1: 2844 added, 1266 left in cavity.
# Round 2: 365 possible centers identified.
# Round 2: 720 added, 375 left in cavity.
# Round 3: 121 possible centers identified.
# Round 3: 228 added, 135 left in cavity.
# Round 4: 45 possible centers identified.
# Round 4: 87 added, 48 left in cavity.
# Round 5: 16 possible centers identified.
# Round 5: 27 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 9 added, 12 left in cavity.
# Round 7: 4 possible centers identified.
# Round 7: 6 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 3 added, 3 left in cavity.
# Round 9: 1 possible centers identified.
# Round 9: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (11000, 3),solute shape (8326, 3)
# Trial 17/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7102 accepted, 5098 left in cavity.
# Round 1: 1368 possible centers identified.
# Round 1: 2901 added, 1203 left in cavity.
# Round 2: 363 possible centers identified.
# Round 2: 759 added, 330 left in cavity.
# Round 3: 100 possible centers identified.
# Round 3: 171 added, 129 left in cavity.
# Round 4: 43 possible centers identified.
# Round 4: 75 added, 54 left in cavity.
# Round 5: 18 possible centers identified.
# Round 5: 27 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 9 added, 18 left in cavity.
# Round 7: 6 possible centers identified.
# Round 7: 12 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 6 added, 0 left in cavity.
# after11155,accepted_coords shape (11062, 3),solute shape (8326, 3)
# Trial 18/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7142 accepted, 5058 left in cavity.
# Round 1: 1377 possible centers identified.
# Round 1: 2850 added, 1281 left in cavity.
# Round 2: 379 possible centers identified.
# Round 2: 720 added, 417 left in cavity.
# Round 3: 133 possible centers identified.
# Round 3: 279 added, 120 left in cavity.
# Round 4: 36 possible centers identified.
# Round 4: 75 added, 33 left in cavity.
# Round 5: 11 possible centers identified.
# Round 5: 12 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 12 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 3 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 0 added, 6 left in cavity.
# after11155,accepted_coords shape (11093, 3),solute shape (8326, 3)
# Trial 19/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7153 accepted, 5047 left in cavity.
# Round 1: 1368 possible centers identified.
# Round 1: 2814 added, 1290 left in cavity.
# Round 2: 385 possible centers identified.
# Round 2: 744 added, 411 left in cavity.
# Round 3: 133 possible centers identified.
# Round 3: 255 added, 144 left in cavity.
# Round 4: 48 possible centers identified.
# Round 4: 105 added, 39 left in cavity.
# Round 5: 13 possible centers identified.
# Round 5: 21 added, 18 left in cavity.
# Round 6: 6 possible centers identified.
# Round 6: 12 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 6 added, 0 left in cavity.
# after11155,accepted_coords shape (11110, 3),solute shape (8326, 3)
# Trial 20/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7042 accepted, 5158 left in cavity.
# Round 1: 1384 possible centers identified.
# Round 1: 2877 added, 1275 left in cavity.
# Round 2: 360 possible centers identified.
# Round 2: 684 added, 396 left in cavity.
# Round 3: 128 possible centers identified.
# Round 3: 243 added, 141 left in cavity.
# Round 4: 47 possible centers identified.
# Round 4: 87 added, 54 left in cavity.
# Round 5: 18 possible centers identified.
# Round 5: 30 added, 24 left in cavity.
# Round 6: 8 possible centers identified.
# Round 6: 15 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 3 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 3 added, 3 left in cavity.
# Round 9: 1 possible centers identified.
# Round 9: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (10987, 3),solute shape (8326, 3)
# Trial 21/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7281 accepted, 4919 left in cavity.
# Round 1: 1312 possible centers identified.
# Round 1: 2727 added, 1209 left in cavity.
# Round 2: 346 possible centers identified.
# Round 2: 696 added, 342 left in cavity.
# Round 3: 104 possible centers identified.
# Round 3: 219 added, 93 left in cavity.
# Round 4: 29 possible centers identified.
# Round 4: 48 added, 39 left in cavity.
# Round 5: 13 possible centers identified.
# Round 5: 27 added, 12 left in cavity.
# Round 6: 4 possible centers identified.
# Round 6: 0 added, 12 left in cavity.
# after11155,accepted_coords shape (10998, 3),solute shape (8326, 3)
# Trial 22/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7083 accepted, 5117 left in cavity.
# Round 1: 1338 possible centers identified.
# Round 1: 2733 added, 1281 left in cavity.
# Round 2: 381 possible centers identified.
# Round 2: 747 added, 396 left in cavity.
# Round 3: 128 possible centers identified.
# Round 3: 285 added, 99 left in cavity.
# Round 4: 33 possible centers identified.
# Round 4: 66 added, 33 left in cavity.
# Round 5: 11 possible centers identified.
# Round 5: 24 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 6 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (10947, 3),solute shape (8326, 3)
# Trial 23/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7199 accepted, 5001 left in cavity.
# Round 1: 1352 possible centers identified.
# Round 1: 2760 added, 1296 left in cavity.
# Round 2: 388 possible centers identified.
# Round 2: 765 added, 399 left in cavity.
# Round 3: 123 possible centers identified.
# Round 3: 252 added, 117 left in cavity.
# Round 4: 37 possible centers identified.
# Round 4: 66 added, 45 left in cavity.
# Round 5: 15 possible centers identified.
# Round 5: 36 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 6 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11155,accepted_coords shape (11084, 3),solute shape (8326, 3)
# Trial 24/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7044 accepted, 5156 left in cavity.
# Round 1: 1386 possible centers identified.
# Round 1: 2868 added, 1290 left in cavity.
# Round 2: 372 possible centers identified.
# Round 2: 729 added, 387 left in cavity.
# Round 3: 119 possible centers identified.
# Round 3: 231 added, 126 left in cavity.
# Round 4: 42 possible centers identified.
# Round 4: 69 added, 57 left in cavity.
# Round 5: 19 possible centers identified.
# Round 5: 42 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 3 added, 12 left in cavity.
# Round 7: 4 possible centers identified.
# Round 7: 12 added, 0 left in cavity.
# after11155,accepted_coords shape (10998, 3),solute shape (8326, 3)
# Trial 25/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7076 accepted, 5124 left in cavity.
# Round 1: 1379 possible centers identified.
# Round 1: 2856 added, 1281 left in cavity.
# Round 2: 380 possible centers identified.
# Round 2: 759 added, 381 left in cavity.
# Round 3: 123 possible centers identified.
# Round 3: 240 added, 129 left in cavity.
# Round 4: 43 possible centers identified.
# Round 4: 87 added, 42 left in cavity.
# Round 5: 14 possible centers identified.
# Round 5: 27 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 3 added, 12 left in cavity.
# Round 7: 4 possible centers identified.
# Round 7: 9 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (11060, 3),solute shape (8326, 3)
# Trial 26/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6954 accepted, 5246 left in cavity.
# Round 1: 1396 possible centers identified.
# Round 1: 2907 added, 1281 left in cavity.
# Round 2: 374 possible centers identified.
# Round 2: 720 added, 402 left in cavity.
# Round 3: 130 possible centers identified.
# Round 3: 249 added, 141 left in cavity.
# Round 4: 45 possible centers identified.
# Round 4: 72 added, 63 left in cavity.
# Round 5: 21 possible centers identified.
# Round 5: 36 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 18 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 6 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 3 added, 0 left in cavity.
# after11155,accepted_coords shape (10965, 3),solute shape (8326, 3)
# Trial 27/50,before11155
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7341 accepted, 4859 left in cavity.
# Round 1: 1316 possible centers identified.
# Round 1: 2754 added, 1194 left in cavity.
# Round 2: 364 possible centers identified.
# Round 2: 711 added, 381 left in cavity.
# Round 3: 123 possible centers identified.
# Round 3: 222 added, 147 left in cavity.
# Round 4: 47 possible centers identified.
# Round 4: 87 added, 54 left in cavity.
# Round 5: 18 possible centers identified.
# Round 5: 30 added, 24 left in cavity.
# Round 6: 8 possible centers identified.
# Round 6: 12 added, 12 left in cavity.
# Round 7: 4 possible centers identified.
# Round 7: 3 added, 9 left in cavity.
# Round 8: 3 possible centers identified.
# Round 8: 6 added, 3 left in cavity.
# Round 9: 1 possible centers identified.
# Round 9: 0 added, 3 left in cavity.
# after11155,accepted_coords shape (11166, 3),solute shape (8326, 3)
# Trial 27 is new best with 11166 added atoms.
# Trial 28/50,before11166
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7093 accepted, 5107 left in cavity.
# Round 1: 1380 possible centers identified.
# Round 1: 2757 added, 1383 left in cavity.
# Round 2: 398 possible centers identified.
# Round 2: 789 added, 405 left in cavity.
# Round 3: 129 possible centers identified.
# Round 3: 255 added, 132 left in cavity.
# Round 4: 40 possible centers identified.
# Round 4: 84 added, 36 left in cavity.
# Round 5: 12 possible centers identified.
# Round 5: 9 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 21 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 6 added, 0 left in cavity.
# after11166,accepted_coords shape (11014, 3),solute shape (8326, 3)
# Trial 29/50,before11166
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7313 accepted, 4887 left in cavity.
# Round 1: 1280 possible centers identified.
# Round 1: 2556 added, 1284 left in cavity.
# Round 2: 376 possible centers identified.
# Round 2: 741 added, 387 left in cavity.
# Round 3: 115 possible centers identified.
# Round 3: 261 added, 84 left in cavity.
# Round 4: 28 possible centers identified.
# Round 4: 75 added, 9 left in cavity.
# Round 5: 3 possible centers identified.
# Round 5: 9 added, 0 left in cavity.
# after11166,accepted_coords shape (10955, 3),solute shape (8326, 3)
# Trial 30/50,before11166
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6994 accepted, 5206 left in cavity.
# Round 1: 1379 possible centers identified.
# Round 1: 2808 added, 1329 left in cavity.
# Round 2: 383 possible centers identified.
# Round 2: 777 added, 372 left in cavity.
# Round 3: 122 possible centers identified.
# Round 3: 258 added, 108 left in cavity.
# Round 4: 36 possible centers identified.
# Round 4: 69 added, 39 left in cavity.
# Round 5: 13 possible centers identified.
# Round 5: 21 added, 18 left in cavity.
# Round 6: 6 possible centers identified.
# Round 6: 3 added, 15 left in cavity.
# Round 7: 5 possible centers identified.
# Round 7: 9 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 6 added, 0 left in cavity.
# after11166,accepted_coords shape (10945, 3),solute shape (8326, 3)
# Trial 31/50,before11166
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7077 accepted, 5123 left in cavity.
# Round 1: 1372 possible centers identified.
# Round 1: 2898 added, 1218 left in cavity.
# Round 2: 352 possible centers identified.
# Round 2: 645 added, 411 left in cavity.
# Round 3: 125 possible centers identified.
# Round 3: 261 added, 114 left in cavity.
# Round 4: 38 possible centers identified.
# Round 4: 72 added, 42 left in cavity.
# Round 5: 14 possible centers identified.
# Round 5: 24 added, 18 left in cavity.
# Round 6: 6 possible centers identified.
# Round 6: 15 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11166,accepted_coords shape (10992, 3),solute shape (8326, 3)
# Trial 32/50,before11166
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7345 accepted, 4855 left in cavity.
# Round 1: 1349 possible centers identified.
# Round 1: 2751 added, 1296 left in cavity.
# Round 2: 372 possible centers identified.
# Round 2: 726 added, 390 left in cavity.
# Round 3: 124 possible centers identified.
# Round 3: 225 added, 147 left in cavity.
# Round 4: 49 possible centers identified.
# Round 4: 93 added, 54 left in cavity.
# Round 5: 18 possible centers identified.
# Round 5: 39 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 6 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 9 added, 0 left in cavity.
# after11166,accepted_coords shape (11194, 3),solute shape (8326, 3)
# Trial 32 is new best with 11194 added atoms.
# Trial 33/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7042 accepted, 5158 left in cavity.
# Round 1: 1386 possible centers identified.
# Round 1: 2871 added, 1287 left in cavity.
# Round 2: 374 possible centers identified.
# Round 2: 774 added, 348 left in cavity.
# Round 3: 114 possible centers identified.
# Round 3: 231 added, 111 left in cavity.
# Round 4: 37 possible centers identified.
# Round 4: 78 added, 33 left in cavity.
# Round 5: 11 possible centers identified.
# Round 5: 18 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 6 added, 9 left in cavity.
# Round 7: 3 possible centers identified.
# Round 7: 3 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 6 added, 0 left in cavity.
# after11194,accepted_coords shape (11029, 3),solute shape (8326, 3)
# Trial 34/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7080 accepted, 5120 left in cavity.
# Round 1: 1361 possible centers identified.
# Round 1: 2844 added, 1239 left in cavity.
# Round 2: 363 possible centers identified.
# Round 2: 768 added, 321 left in cavity.
# Round 3: 107 possible centers identified.
# Round 3: 159 added, 162 left in cavity.
# Round 4: 54 possible centers identified.
# Round 4: 111 added, 51 left in cavity.
# Round 5: 17 possible centers identified.
# Round 5: 30 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 3 added, 18 left in cavity.
# Round 7: 6 possible centers identified.
# Round 7: 12 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 0 added, 6 left in cavity.
# after11194,accepted_coords shape (11007, 3),solute shape (8326, 3)
# Trial 35/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6838 accepted, 5362 left in cavity.
# Round 1: 1423 possible centers identified.
# Round 1: 3021 added, 1248 left in cavity.
# Round 2: 359 possible centers identified.
# Round 2: 744 added, 333 left in cavity.
# Round 3: 107 possible centers identified.
# Round 3: 228 added, 93 left in cavity.
# Round 4: 31 possible centers identified.
# Round 4: 63 added, 30 left in cavity.
# Round 5: 10 possible centers identified.
# Round 5: 24 added, 6 left in cavity.
# Round 6: 2 possible centers identified.
# Round 6: 3 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 3 added, 0 left in cavity.
# after11194,accepted_coords shape (10924, 3),solute shape (8326, 3)
# Trial 36/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7294 accepted, 4906 left in cavity.
# Round 1: 1327 possible centers identified.
# Round 1: 2661 added, 1320 left in cavity.
# Round 2: 379 possible centers identified.
# Round 2: 780 added, 357 left in cavity.
# Round 3: 111 possible centers identified.
# Round 3: 234 added, 99 left in cavity.
# Round 4: 31 possible centers identified.
# Round 4: 42 added, 51 left in cavity.
# Round 5: 17 possible centers identified.
# Round 5: 24 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 15 added, 12 left in cavity.
# Round 7: 4 possible centers identified.
# Round 7: 6 added, 6 left in cavity.
# Round 8: 2 possible centers identified.
# Round 8: 6 added, 0 left in cavity.
# after11194,accepted_coords shape (11062, 3),solute shape (8326, 3)
# Trial 37/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6839 accepted, 5361 left in cavity.
# Round 1: 1452 possible centers identified.
# Round 1: 2922 added, 1434 left in cavity.
# Round 2: 431 possible centers identified.
# Round 2: 873 added, 420 left in cavity.
# Round 3: 136 possible centers identified.
# Round 3: 246 added, 162 left in cavity.
# Round 4: 52 possible centers identified.
# Round 4: 105 added, 51 left in cavity.
# Round 5: 17 possible centers identified.
# Round 5: 30 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 18 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11194,accepted_coords shape (11033, 3),solute shape (8326, 3)
# Trial 38/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7302 accepted, 4898 left in cavity.
# Round 1: 1317 possible centers identified.
# Round 1: 2715 added, 1236 left in cavity.
# Round 2: 361 possible centers identified.
# Round 2: 699 added, 384 left in cavity.
# Round 3: 122 possible centers identified.
# Round 3: 243 added, 123 left in cavity.
# Round 4: 39 possible centers identified.
# Round 4: 69 added, 48 left in cavity.
# Round 5: 16 possible centers identified.
# Round 5: 30 added, 18 left in cavity.
# Round 6: 6 possible centers identified.
# Round 6: 12 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 3 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 3 added, 0 left in cavity.
# after11194,accepted_coords shape (11076, 3),solute shape (8326, 3)
# Trial 39/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7080 accepted, 5120 left in cavity.
# Round 1: 1389 possible centers identified.
# Round 1: 2799 added, 1368 left in cavity.
# Round 2: 389 possible centers identified.
# Round 2: 786 added, 381 left in cavity.
# Round 3: 123 possible centers identified.
# Round 3: 249 added, 120 left in cavity.
# Round 4: 40 possible centers identified.
# Round 4: 84 added, 36 left in cavity.
# Round 5: 12 possible centers identified.
# Round 5: 27 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 6 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11194,accepted_coords shape (11031, 3),solute shape (8326, 3)
# Trial 40/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6970 accepted, 5230 left in cavity.
# Round 1: 1440 possible centers identified.
# Round 1: 2889 added, 1431 left in cavity.
# Round 2: 410 possible centers identified.
# Round 2: 798 added, 432 left in cavity.
# Round 3: 134 possible centers identified.
# Round 3: 264 added, 138 left in cavity.
# Round 4: 44 possible centers identified.
# Round 4: 84 added, 48 left in cavity.
# Round 5: 16 possible centers identified.
# Round 5: 39 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 3 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 0 added, 6 left in cavity.
# after11194,accepted_coords shape (11047, 3),solute shape (8326, 3)
# Trial 41/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7221 accepted, 4979 left in cavity.
# Round 1: 1342 possible centers identified.
# Round 1: 2838 added, 1188 left in cavity.
# Round 2: 360 possible centers identified.
# Round 2: 732 added, 348 left in cavity.
# Round 3: 104 possible centers identified.
# Round 3: 210 added, 102 left in cavity.
# Round 4: 34 possible centers identified.
# Round 4: 57 added, 45 left in cavity.
# Round 5: 15 possible centers identified.
# Round 5: 30 added, 15 left in cavity.
# Round 6: 5 possible centers identified.
# Round 6: 12 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11194,accepted_coords shape (11100, 3),solute shape (8326, 3)
# Trial 42/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7048 accepted, 5152 left in cavity.
# Round 1: 1415 possible centers identified.
# Round 1: 2937 added, 1308 left in cavity.
# Round 2: 370 possible centers identified.
# Round 2: 738 added, 372 left in cavity.
# Round 3: 122 possible centers identified.
# Round 3: 225 added, 141 left in cavity.
# Round 4: 47 possible centers identified.
# Round 4: 72 added, 69 left in cavity.
# Round 5: 23 possible centers identified.
# Round 5: 57 added, 12 left in cavity.
# Round 6: 4 possible centers identified.
# Round 6: 6 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 6 added, 0 left in cavity.
# after11194,accepted_coords shape (11089, 3),solute shape (8326, 3)
# Trial 43/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6965 accepted, 5235 left in cavity.
# Round 1: 1381 possible centers identified.
# Round 1: 2940 added, 1203 left in cavity.
# Round 2: 353 possible centers identified.
# Round 2: 720 added, 339 left in cavity.
# Round 3: 109 possible centers identified.
# Round 3: 198 added, 129 left in cavity.
# Round 4: 41 possible centers identified.
# Round 4: 78 added, 45 left in cavity.
# Round 5: 15 possible centers identified.
# Round 5: 33 added, 12 left in cavity.
# Round 6: 4 possible centers identified.
# Round 6: 6 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 3 added, 3 left in cavity.
# Round 8: 1 possible centers identified.
# Round 8: 3 added, 0 left in cavity.
# after11194,accepted_coords shape (10946, 3),solute shape (8326, 3)
# Trial 44/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7111 accepted, 5089 left in cavity.
# Round 1: 1348 possible centers identified.
# Round 1: 2745 added, 1299 left in cavity.
# Round 2: 388 possible centers identified.
# Round 2: 735 added, 429 left in cavity.
# Round 3: 133 possible centers identified.
# Round 3: 255 added, 144 left in cavity.
# Round 4: 48 possible centers identified.
# Round 4: 78 added, 66 left in cavity.
# Round 5: 22 possible centers identified.
# Round 5: 39 added, 27 left in cavity.
# Round 6: 9 possible centers identified.
# Round 6: 12 added, 15 left in cavity.
# Round 7: 5 possible centers identified.
# Round 7: 6 added, 9 left in cavity.
# Round 8: 3 possible centers identified.
# Round 8: 6 added, 3 left in cavity.
# Round 9: 1 possible centers identified.
# Round 9: 3 added, 0 left in cavity.
# after11194,accepted_coords shape (10990, 3),solute shape (8326, 3)
# Trial 45/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7038 accepted, 5162 left in cavity.
# Round 1: 1406 possible centers identified.
# Round 1: 2916 added, 1302 left in cavity.
# Round 2: 372 possible centers identified.
# Round 2: 804 added, 312 left in cavity.
# Round 3: 102 possible centers identified.
# Round 3: 195 added, 111 left in cavity.
# Round 4: 37 possible centers identified.
# Round 4: 54 added, 57 left in cavity.
# Round 5: 19 possible centers identified.
# Round 5: 39 added, 18 left in cavity.
# Round 6: 6 possible centers identified.
# Round 6: 15 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11194,accepted_coords shape (11061, 3),solute shape (8326, 3)
# Trial 46/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6948 accepted, 5252 left in cavity.
# Round 1: 1442 possible centers identified.
# Round 1: 2976 added, 1350 left in cavity.
# Round 2: 414 possible centers identified.
# Round 2: 831 added, 411 left in cavity.
# Round 3: 135 possible centers identified.
# Round 3: 282 added, 123 left in cavity.
# Round 4: 39 possible centers identified.
# Round 4: 69 added, 48 left in cavity.
# Round 5: 16 possible centers identified.
# Round 5: 24 added, 24 left in cavity.
# Round 6: 8 possible centers identified.
# Round 6: 21 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 0 added, 3 left in cavity.
# after11194,accepted_coords shape (11151, 3),solute shape (8326, 3)
# Trial 47/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6929 accepted, 5271 left in cavity.
# Round 1: 1421 possible centers identified.
# Round 1: 3009 added, 1254 left in cavity.
# Round 2: 363 possible centers identified.
# Round 2: 723 added, 366 left in cavity.
# Round 3: 118 possible centers identified.
# Round 3: 243 added, 111 left in cavity.
# Round 4: 37 possible centers identified.
# Round 4: 60 added, 51 left in cavity.
# Round 5: 17 possible centers identified.
# Round 5: 30 added, 21 left in cavity.
# Round 6: 7 possible centers identified.
# Round 6: 15 added, 6 left in cavity.
# Round 7: 2 possible centers identified.
# Round 7: 6 added, 0 left in cavity.
# after11194,accepted_coords shape (11015, 3),solute shape (8326, 3)
# Trial 48/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7131 accepted, 5069 left in cavity.
# Round 1: 1405 possible centers identified.
# Round 1: 2922 added, 1293 left in cavity.
# Round 2: 373 possible centers identified.
# Round 2: 744 added, 375 left in cavity.
# Round 3: 121 possible centers identified.
# Round 3: 213 added, 150 left in cavity.
# Round 4: 50 possible centers identified.
# Round 4: 87 added, 63 left in cavity.
# Round 5: 21 possible centers identified.
# Round 5: 33 added, 30 left in cavity.
# Round 6: 10 possible centers identified.
# Round 6: 3 added, 27 left in cavity.
# Round 7: 9 possible centers identified.
# Round 7: 27 added, 0 left in cavity.
# after11194,accepted_coords shape (11160, 3),solute shape (8326, 3)
# Trial 49/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 7066 accepted, 5134 left in cavity.
# Round 1: 1360 possible centers identified.
# Round 1: 2763 added, 1317 left in cavity.
# Round 2: 377 possible centers identified.
# Round 2: 774 added, 357 left in cavity.
# Round 3: 105 possible centers identified.
# Round 3: 195 added, 120 left in cavity.
# Round 4: 38 possible centers identified.
# Round 4: 87 added, 27 left in cavity.
# Round 5: 9 possible centers identified.
# Round 5: 18 added, 9 left in cavity.
# Round 6: 3 possible centers identified.
# Round 6: 9 added, 0 left in cavity.
# after11194,accepted_coords shape (10912, 3),solute shape (8326, 3)
# Trial 50/50,before11194
# Generated 12200 initial solvent candidates.
# After Round 1 overlap removal: 6924 accepted, 5276 left in cavity.
# Round 1: 1429 possible centers identified.
# Round 1: 2850 added, 1437 left in cavity.
# Round 2: 420 possible centers identified.
# Round 2: 837 added, 423 left in cavity.
# Round 3: 135 possible centers identified.
# Round 3: 258 added, 147 left in cavity.
# Round 4: 49 possible centers identified.
# Round 4: 90 added, 57 left in cavity.
# Round 5: 19 possible centers identified.
# Round 5: 39 added, 18 left in cavity.
# Round 6: 6 possible centers identified.
# Round 6: 15 added, 3 left in cavity.
# Round 7: 1 possible centers identified.
# Round 7: 3 added, 0 left in cavity.
# after11194,accepted_coords shape (11016, 3),solute shape (8326, 3)
# 19520 atoms written to solvated_structure.xyz
# Best trial added 11194 solvent atoms.
# (array([[11.042     , -2.826     , 10.44      ],
#         [10.066     , -1.973     , 11.007     ],
#         [ 9.257     , -2.138     ,  9.859     ],
#         ...,
#         [22.12479607,  7.92882089,  9.89420294],
#         [21.2038733 ,  8.09331263,  9.56947691],
#         [22.25852514,  6.95454096,  9.77802259]]),
#  array(['D', 'D', 'D', ..., 'O', 'H', 'H'], dtype='<U32'))
